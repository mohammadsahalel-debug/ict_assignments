# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammadsahalel-debug/ict_assignments/blob/main/project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
9. ''''Text-Based Decision Game
Create a text-based decision-making game.
The game should present players with scenarios where choices affect the storyline and
score. Multiple story paths and endings must exist.
The system should track decisions, compute scores, and allow replayability. String
processing and conditional branching are core requirements.'''''

# %%
score = 0
print("wELCOME TO THE ADVENTURE GAME")
print("You are at the entrance of a forest.")
print("1. Enter the forest")
print("2. go back home")
choice1 = input("Enter your choice (1 or 2): ")
if choice1 == "1":
    score = score + 10
    print("You entered the forest.")
    print("You see a river.")
    print("1. Drink water")
    print("2. Walk away")
    choice2 = input("Enter your choice (1 or 2): ")
    if choice2 == "1":
        score = score + 10
        print("You feel refreshed.")
        print("GOOD ENDING: You survived the forest.")
    else:
        score = score + 5
        print("You got lost but found your way out")
        print("NORMAL ENDING")
else:
    print("You went back home safely.")
    print("SAFE ENDING.")
    print("Your final score is:",score)
# Out:
# wELCOME TO THE ADVENTURE GAME
# You are at the entrance of a forest.
# 1. Enter the forest
# 2. go back home
# Enter your choice (1 or 2): 1
# You entered the forest.
# You see a river.
# 1. Drink water
# 2. Walk away
# Enter your choice (1 or 2): 1
# You feel refreshed.
# GOOD ENDING: You survived the forest.

# %%
3. ''''Campus Store Inventory and Billing System
Develop a console-based Inventory and Billing System for a campus store.
The program should allow administrators to add products, update stock levels, and define prices.
Customers should be able to purchase multiple products in a single transaction.
The system must automatically generate bills showing item-wise cost, subtotal, tax, discount
(based on slabs), and final payable amount. Stock levels should update dynamically, and
low-stock alerts should be displayed.
Negative stock values must be prevented through validation logic. Use dictionaries for
inventory management and lists for cart handling

# %%
store = {
    "pen": [10, 20],
    "book": [50, 10]
}
print("WELCOME TO CAMPUS STORE")
print("Items available:")
print("Pen - Price:", store["pen"][0], "Stock:", store["pen"][1])
print("Book - Price:", store["book"][0], "Stock:", store["book"][1])
item = input("Enter item name (pen/book): ")
qty = int(input("Enter quantity: "))
if item in store:
    if qty <= store[item][1]:
        total = qty * store[item][0]
        store[item][1] = store[item][1] - qty
        print("Total amount:", total)
        print("Purchase successful")
    else:
        print("Not enough stock")
else:
    print("Item not found")

print("Thank you for shopping")
# Out:
# WELCOME TO CAMPUS STORE
# Items available:
# Pen - Price: 10 Stock: 20
# Book - Price: 50 Stock: 10
# Enter item name (pen/book): pen
# Enter quantity: 5
# Total amount: 50
# Purchase successful
# Thank you for shopping
